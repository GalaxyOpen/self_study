# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# 한글 폰트 설치
# !apt-get -qq -y install fonts-nanum

# %%
# 한글 폰트 표시를 잘하도록 하기
import matplotlib.pyplot as plt
from matplotlib import font_manager, rc

font_path = '/usr/share/fonts/truetype/nanum/NanumGothic.ttf'
font = font_manager.FontProperties(fname=font_path).get_name()
rc('font', family=font)

plt.rcParams['axes.unicode_minus'] = False  # 마이너스 기호 깨짐 방지

# %%
# 전에 우선 3 파일을 구글 콜랩에 업로드를 해야함(필수)
# !pip install koreanize_matplotlib-0.1.1-py3-none-any.whl
# !pip install mplfinance-0.12.10b0-py3-none-any.whl
# !pip install finance_datareader-0.9.94-py3-none-any.whl
# Out:
# Processing ./koreanize_matplotlib-0.1.1-py3-none-any.whl
# ...
# koreanize-matplotlib is already installed with the same version as the provided wheel. Use --force-reinstall to force an installation of the wheel.
# Processing ./mplfinance-0.12.10b0-py3-none-any.whl
# ...
# mplfinance is already installed with the same version as the provided wheel. Use --force-reinstall to force an installation of the wheel.
# Processing ./finance_datareader-0.9.94-py3-none-any.whl
# ...
# finance-datareader is already installed with the same version as the provided wheel. Use --force-reinstall to force an installation of the wheel.

# %%
import FinanceDataReader as fdr # 애플 주식 데이터 (2022년) 중 일부
import koreanize_matplotlib # 한글이 포함된 플롯을 임포트하는 구문
import mplfinance as mpf # 불러운 주식 데이터를 사용해 캔들스틱 차트를 표시함.

# %%
import FinanceDataReader as fdr
# '005930' 삼성전자
# 'AAPL' 애플
df = fdr.DataReader('AAPL', '2024-01-01', '2024-12-31')
df
# Out:
#                   Open        High         Low       Close    Volume  \
# 2024-01-02  187.149994  188.440002  183.889999  185.639999  82488700
# 2024-01-03  184.220001  185.880005  183.429993  184.250000  58414500
# 2024-01-04  182.149994  183.089996  180.880005  181.910004  71983600
# 2024-01-05  181.990005  182.759995  180.169998  181.179993  62303300
# 2024-01-08  182.089996  185.600006  181.500000  185.559998  59144500
# ...                ...         ...         ...         ...       ...
# 2024-12-23  254.770004  255.649994  253.449997  255.270004  40858800
# 2024-12-24  255.490005  258.209991  255.289993  258.200012  23234700
# 2024-12-26  258.190002  260.100006  257.630005  259.019989  27237100
# 2024-12-27  257.829987  258.700012  253.059998  255.589996  42355300
# 2024-12-30  252.229996  253.500000  250.750000  252.199997  35557500
#
#              Adj Close
# 2024-01-02  184.532089
# 2024-01-03  183.150375
# 2024-01-04  180.824356
# 2024-01-05  180.098694
# ...

# %%
import mplfinance as mpf
import koreanize_matplotlib
mpf.plot(df, type='candle', style='yahoo', title='apple stock Data', mav=(5, 10))

# %%
import FinanceDataReader as fdr
import mplfinance as mpf

# 애플 주식 데이터 불러오기
df_apple = fdr.DataReader('AAPL', '2024-01-01', '2024-01-31')

# 애플 주식 데이터 시각화
mpf.plot(df_apple, type='candle', style='yahoo', title='apple stock data', mav=(5, 10))
